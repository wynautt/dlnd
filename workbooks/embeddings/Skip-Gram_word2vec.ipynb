# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:01, 511KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

def p_wi(word, word_freqs, threshold=1e-5):
    return 1 - np.sqrt(threshold / word_freqs[word])

word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: p_wi(word, freqs) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size + 1)
    start_idx = max(0, idx - R)
    end_idx = min(len(words) - 1, idx + R)
    
    return list(set(words[start_idx:idx] + words[idx+1:end_idx+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)

    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6514 0.2794 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6315 0.3666 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5005 0.3286 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5860 0.2798 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5026 0.2809 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5855 0.2814 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5773 0.2821 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5731 0.2777 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4610 0.2833 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3917 0.2805 sec/batch
# Nearest to people: msil, laparoscopic, childbirth, fortuitous, caribou, invert, amphetamine, fishing,
# Nearest to after: cornell, vocalist, wilder, bratislava, wore, baer, oder, mercury,
# Nearest to states: patio, pandavas, fuss, schists, csx, transform, globin, broadcasting,
# Nearest to d: storytelling, ous, valdes, socrates, motto, geologists, cave, flautist,
# Nearest to history: bain, pinches, glaze, bottlers, glade, hwang, plc, edlin,
# Nearest to and: axons, dentist, southend, colecovision, pos, dass, hfr, recasting,
# Nearest to however: abrahamic, haskell, contemplate, wg, bahia, childress, collectivism, discernment,
# Nearest to at: convenience, separately, cyclades, force, interlocutor, gesture, medley, ganges,
# Nearest to active: slopes, fielding, briefcase, judicially, libreville, nta, kroto, woman,
# Nearest to animals: afterwards, classicism, aqueous, canoeing, bicontinental, wolof, phan, vlaams,
# Nearest to report: erroneously, gemstones, mycelium, freude, idempotent, subscripts, sabatini, hawthorn,
# Nearest to creation: molloy, woodcuts, coatings, port, presented, polling, koan, monotonous,
# Nearest to freedom: dedication, morality, kylix, lyra, deimos, subjecting, tsu, publius,
# Nearest to notes: ewell, uncharacteristic, deposing, richmond, panarion, scriptores, bufo, excitable,
# Nearest to primarily: monmouth, kinesthetic, particularly, switchable, inflammations, amphetamine, dora, muhammed,
# Nearest to engineering: openness, altaic, forwarding, bali, retrospect, fictionalised, versioning, scientologist,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4703 0.2856 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3541 0.3123 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3307 0.2956 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2384 0.2972 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1640 0.3135 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1810 0.3187 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0713 0.3170 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0744 0.3144 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9723 0.3140 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9702 0.3152 sec/batch
# Nearest to people: childbirth, laparoscopic, msil, development, met, several, previously, establish,
# Nearest to after: wore, cornell, wilder, oder, vocalist, conferred, baer, mercury,
# Nearest to states: audiences, csx, satisfy, establishing, broadcasting, developer, transform, plays,
# Nearest to d: storytelling, socrates, geologists, valdes, include, doctrine, motto, touch,
# Nearest to history: bain, country, pinches, mainstay, bottlers, hwang, due, cannons,
# Nearest to and: axons, administration, links, dentist, intake, level, unlike, pos,
# Nearest to however: abrahamic, marked, bahia, contemplate, collectivism, haskell, demonstrated, childress,
# Nearest to at: force, separately, convenience, to, leadership, cyclades, gesture, all,
# Nearest to active: slopes, woman, funding, schools, fielding, judicially, supplemental, deals,
# Nearest to animals: afterwards, aqueous, classicism, cryopreserved, piece, rejecting, principles, phan,
# Nearest to report: erroneously, gemstones, idempotent, decades, units, acquired, nearly, mosby,
# Nearest to creation: presented, molloy, port, parallel, woodcuts, coatings, koan, polling,
# Nearest to freedom: morality, dedication, kylix, writings, viewing, neglected, insulated, deimos,
# Nearest to notes: being, medically, richmond, agencies, deposing, ewell, compromise, scriptores,
# Nearest to primarily: particularly, monmouth, arrow, sculley, moves, switchable, million, amphetamine,
# Nearest to engineering: altaic, openness, straight, articles, forwarding, concretely, chinese, versioning,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9317 0.3216 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9065 0.3167 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8808 0.3175 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8624 0.3323 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7775 0.3218 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8092 0.3231 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7952 0.3305 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8021 0.3351 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7903 0.3293 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7820 0.3223 sec/batch
# Nearest to people: childbirth, laparoscopic, msil, development, fishing, fortuitous, establish, previously,
# Nearest to after: oder, wore, cornell, vocalist, conferences, agreements, wilder, seamus,
# Nearest to states: audiences, csx, broadcasting, weimar, satisfy, transform, recommendation, establishing,
# Nearest to d: storytelling, motto, valdes, geologists, socrates, robinson, doctrine, commanded,
# Nearest to history: bain, pinches, country, mainstay, crashed, plc, hwang, cannons,
# Nearest to and: axons, administration, pos, intake, dentist, unlike, think, coms,
# Nearest to however: abrahamic, collectivism, haskell, marked, contemplate, bahia, despotism, discernment,
# Nearest to at: force, convenience, separately, leadership, climbing, auction, gesture, cyclades,
# Nearest to active: slopes, funding, woman, fielding, frank, schools, judicially, practising,
# Nearest to animals: afterwards, aqueous, classicism, cryopreserved, principles, tapes, rejecting, updated,
# Nearest to report: erroneously, gemstones, idempotent, decades, units, beneficial, mycelium, hawthorn,
# Nearest to creation: molloy, presented, port, woodcuts, coatings, polling, parallel, koan,
# Nearest to freedom: morality, dedication, kylix, writings, viewing, publius, insulated, neglected,
# Nearest to notes: richmond, deposing, ewell, agencies, medically, being, scriptores, uncharacteristic,
# Nearest to primarily: particularly, monmouth, sculley, arrow, moves, switchable, faces, actions,
# Nearest to engineering: openness, altaic, forwarding, concretely, estates, versioning, straight, articles,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7747 0.3271 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7317 0.3206 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7143 0.3253 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7016 0.3253 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7361 0.3212 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7025 0.3271 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7013 0.3246 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7368 0.3218 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6978 0.3328 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6525 0.2909 sec/batch
# Nearest to people: childbirth, laparoscopic, msil, fortuitous, establish, development, met, fishing,
# Nearest to after: oder, cornell, wore, vocalist, linebacker, conferences, agreements, iamblichus,
# Nearest to states: weimar, faring, audiences, establishing, csx, west, persecutors, broadcasting,
# Nearest to d: motto, valdes, robinson, zquez, chemist, one, comedian, storytelling,
# Nearest to history: bain, pinches, country, mainstay, hwang, crashed, glade, cannons,
# Nearest to and: axons, sinn, dentist, administration, leaps, intake, pos, allegorical,
# Nearest to however: abrahamic, collectivism, haskell, contemplate, demonstrated, despotism, wg, discernment,
# Nearest to at: force, convenience, leadership, climbing, separately, interlocutor, dependents, auction,
# Nearest to active: slopes, funding, woman, supplemental, libreville, schools, fielding, practising,
# Nearest to animals: afterwards, aqueous, classicism, cryopreserved, starts, mammals, tapes, canoeing,
# Nearest to report: gemstones, erroneously, idempotent, proletarians, decades, brane, hawthorn, mycelium,
# Nearest to creation: molloy, presented, coatings, woodcuts, polling, port, brythonic, koan,
# Nearest to freedom: morality, dedication, kylix, publius, writings, dug, tsu, deimos,
# Nearest to notes: richmond, ewell, deposing, uncharacteristic, being, melilla, panarion, moab,
# Nearest to primarily: monmouth, particularly, sculley, switchable, kinesthetic, dora, pertain, moves,
# Nearest to engineering: openness, altaic, forwarding, concretely, fictionalised, versioning, retrospect, straight,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6599 0.2904 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6687 0.2793 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6202 0.2796 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6363 0.2845 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6417 0.2806 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6487 0.2858 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5789 0.2062 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5616 0.2859 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5310 0.2770 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5216 0.2853 sec/batch
# Nearest to people: childbirth, laparoscopic, msil, establish, fortuitous, development, met, inh,
# Nearest to after: oder, cornell, wore, vocalist, conferences, sandburg, linebacker, seamus,
# Nearest to states: weimar, faring, north, west, establishing, persecutors, nikolay, andreas,
# Nearest to d: chemist, comedian, one, composer, b, politician, painter, elliott,
# Nearest to history: bain, pinches, country, mainstay, crashed, hwang, glaze, printing,
# Nearest to and: axons, sinn, intake, leaps, wields, dentist, coms, blacked,
# Nearest to however: abrahamic, collectivism, despotism, contemplate, demonstrated, haskell, wg, determining,
# Nearest to at: force, interlocutor, climbing, convenience, ireann, leadership, gander, macedonia,
# Nearest to active: slopes, funding, supplemental, libreville, practising, fielding, woman, schools,
# Nearest to animals: afterwards, aqueous, starts, cryopreserved, mammals, boastful, hardening, classicism,
# Nearest to report: gemstones, erroneously, idempotent, unease, mycelium, hawthorn, proletarians, imitative,
# Nearest to creation: molloy, presented, coatings, woodcuts, polling, koan, brythonic, monotonous,
# Nearest to freedom: morality, dedication, kylix, publius, writings, dug, deimos, trebizond,
# Nearest to notes: richmond, ewell, deposing, uncharacteristic, panarion, being, tripod, habitually,
# Nearest to primarily: monmouth, particularly, kinesthetic, switchable, sculley, inflammations, shift, dora,
# Nearest to engineering: fictionalised, forwarding, openness, versioning, altaic, retrospect, concretely, straight,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4987 0.2805 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4975 0.2781 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4627 0.2816 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5094 0.2755 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4769 0.2779 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4705 0.2827 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4824 0.2770 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3926 0.2770 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4326 0.2764 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4155 0.2874 sec/batch
# Nearest to people: laparoscopic, msil, childbirth, establish, development, fortuitous, inh, trafficking,
# Nearest to after: oder, wore, cornell, vocalist, linebacker, sandburg, seamus, to,
# Nearest to states: weimar, faring, north, nikolay, czar, representatives, west, haworth,
# Nearest to d: chemist, composer, politician, painter, elliott, zquez, comedian, robinson,
# Nearest to history: bain, country, pinches, hwang, glaze, mainstay, bottlers, tallahassee,
# Nearest to and: intake, axons, dentist, leaps, unlike, coms, wields, directv,
# Nearest to however: abrahamic, collectivism, despotism, haskell, demonstrated, apex, contemplate, wg,
# Nearest to at: force, interlocutor, climbing, convenience, cyclades, oppositional, ireann, altenburg,
# Nearest to active: slopes, libreville, funding, supplemental, schools, briefcase, herut, constituents,
# Nearest to animals: aqueous, afterwards, starts, mammals, wolof, boastful, cryopreserved, hardening,
# Nearest to report: gemstones, erroneously, idempotent, mycelium, unease, camra, proletarians, hawthorn,
# Nearest to creation: molloy, presented, polling, woodcuts, coatings, canon, koan, tatian,
# Nearest to freedom: morality, dedication, writings, kylix, publius, dug, discontinuing, trebizond,
# Nearest to notes: ewell, uncharacteristic, deposing, tripod, excitable, panarion, richmond, being,
# Nearest to primarily: monmouth, particularly, kinesthetic, switchable, inflammations, moves, shift, arrow,
# Nearest to engineering: systems, fictionalised, versioning, forwarding, openness, scientologist, retrospect, bokassa,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4418 0.2836 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3940 0.2817 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4414 0.2763 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4009 0.2778 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3999 0.2787 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4156 0.2775 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3842 0.2815 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3800 0.2807 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4220 0.2856 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3920 0.2845 sec/batch
# Nearest to people: laparoscopic, msil, childbirth, development, establish, inh, fortuitous, met,
# Nearest to after: oder, wore, cornell, vocalist, collaborated, badly, lop, linebacker,
# Nearest to states: weimar, faring, representatives, north, haworth, nikolay, czar, enacted,
# Nearest to d: chemist, b, zquez, elliott, flautist, leopold, composer, valdes,
# Nearest to history: bain, glaze, hwang, country, pinches, rawls, tallahassee, mainstay,
# Nearest to and: dentist, intake, raf, directv, axons, barbecue, leaps, blacked,
# Nearest to however: abrahamic, collectivism, despotism, contemplate, determining, discernment, wg, haskell,
# Nearest to at: force, interlocutor, climbing, ireann, semite, convenience, cyclades, pupil,
# Nearest to active: slopes, libreville, funding, supplemental, herut, constituents, briefcase, schools,
# Nearest to animals: aqueous, mammals, starts, wolof, hardening, afterwards, boastful, deciphering,
# Nearest to report: gemstones, erroneously, idempotent, mycelium, proletarians, boroughs, unease, bosnians,
# Nearest to creation: presented, molloy, woodcuts, polling, tatian, coatings, koan, dichotomy,
# Nearest to freedom: morality, dedication, writings, kylix, publius, dug, trebizond, discontinuing,
# Nearest to notes: ewell, uncharacteristic, deposing, richmond, excitable, panarion, tripod, habitually,
# Nearest to primarily: monmouth, particularly, kinesthetic, switchable, arrow, inflammations, amphetamine, shift,
# Nearest to engineering: systems, versioning, fictionalised, forwarding, openness, bokassa, straight, scientologist,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3979 0.2882 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4046 0.2874 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3794 0.2894 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3909 0.2907 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3868 0.2970 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3725 0.2775 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3577 0.2767 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3683 0.3052 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3198 0.2783 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3456 0.2768 sec/batch
# Nearest to people: laparoscopic, msil, childbirth, establish, inh, development, trafficking, met,
# Nearest to after: oder, wore, cornell, badly, landed, to, vocalist, theorizes,
# Nearest to states: weimar, faring, representatives, enacted, govern, north, czar, haworth,
# Nearest to d: chemist, elliott, zquez, b, flautist, apparitions, valdes, fantagraphics,
# Nearest to history: bain, hwang, glaze, country, pinches, rawls, friesland, mainstay,
# Nearest to and: intake, dentist, directv, rouen, unlike, hfr, rajendra, raf,
# Nearest to however: abrahamic, collectivism, despotism, contemplate, mocks, discernment, eurofighter, apex,
# Nearest to at: force, interlocutor, climbing, semite, convenience, ireann, shankar, cyclades,
# Nearest to active: slopes, libreville, funding, constituents, supplemental, schools, basaltic, herut,
# Nearest to animals: mammals, aqueous, wolof, afterwards, hardening, starts, agricultural, sensory,
# Nearest to report: gemstones, idempotent, erroneously, bosnians, boroughs, proletarians, unease, camra,
# Nearest to creation: presented, molloy, woodcuts, polling, tatian, homosexuals, dichotomy, coatings,
# Nearest to freedom: morality, dedication, kylix, publius, dug, trebizond, writings, of,
# Nearest to notes: uncharacteristic, ewell, deposing, excitable, habitually, panarion, richmond, bugtraq,
# Nearest to primarily: monmouth, kinesthetic, particularly, switchable, amphetamine, inflammations, dihedral, sculley,
# Nearest to engineering: systems, versioning, forwarding, fictionalised, openness, bokassa, pokey, scientologist,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3713 0.2823 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2854 0.3062 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3727 0.2789 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3627 0.2775 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3826 0.2776 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3025 0.2965 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3072 0.3117 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3461 0.2865 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2275 0.2802 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2810 0.2799 sec/batch
# Nearest to people: msil, childbirth, laparoscopic, inh, establish, development, trafficking, fishing,
# Nearest to after: oder, wore, landed, cornell, badly, linebacker, paveway, sandburg,
# Nearest to states: weimar, faring, north, representatives, galway, charlestown, czar, establishing,
# Nearest to d: chemist, b, elliott, painter, astronomer, composer, architect, physicist,
# Nearest to history: bain, hwang, glaze, pinches, country, rawls, printing, fanfic,
# Nearest to and: intake, directv, dentist, rouen, of, demosthenes, leaps, improv,
# Nearest to however: abrahamic, collectivism, despotism, contemplate, apex, determining, eurofighter, vulnerabilities,
# Nearest to at: force, interlocutor, climbing, kingston, altenburg, shankar, cyclades, mmix,
# Nearest to active: slopes, libreville, supplemental, herut, basaltic, funding, schools, inoculation,
# Nearest to animals: mammals, aqueous, wolof, afterwards, hardening, paleocene, agricultural, sensory,
# Nearest to report: gemstones, idempotent, bosnians, erroneously, boroughs, henriques, wavell, coria,
# Nearest to creation: presented, molloy, woodcuts, tatian, dichotomy, polling, comprehensive, edging,
# Nearest to freedom: morality, dedication, publius, kylix, dug, trebizond, writings, of,
# Nearest to notes: uncharacteristic, ewell, panarion, excitable, jerk, bugtraq, decidedly, habitually,
# Nearest to primarily: monmouth, particularly, kinesthetic, switchable, amphetamine, dihedral, sculley, shift,
# Nearest to engineering: systems, versioning, fictionalised, bokassa, forwarding, openness, pokey, altaic,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3027 0.2821 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3005 0.2766 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3446 0.1288 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2486 0.2794 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2217 0.2798 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2283 0.2806 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2380 0.2784 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2061 0.2805 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2346 0.2790 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1810 0.2788 sec/batch
# Nearest to people: msil, childbirth, inh, laparoscopic, trafficking, establish, fishing, caribou,
# Nearest to after: oder, wore, to, badly, landed, paveway, entered, cornell,
# Nearest to states: weimar, faring, united, galway, north, charlestown, haworth, czar,
# Nearest to d: b, chemist, elliott, painter, zquez, astronomer, composer, leopold,
# Nearest to history: bain, hwang, glaze, encyclopedia, printing, country, fanfic, rawls,
# Nearest to and: intake, dentist, directv, demosthenes, evangelica, rouen, improv, leaps,
# Nearest to however: abrahamic, collectivism, despotism, contemplate, discernment, eunos, somatic, vulnerabilities,
# Nearest to at: force, interlocutor, climbing, kingston, donatists, casualties, nh, home,
# Nearest to active: slopes, supplemental, libreville, inoculation, basaltic, funding, herut, constituents,
# Nearest to animals: mammals, aqueous, wolof, species, breeding, agricultural, afterwards, ecology,
# Nearest to report: idempotent, gemstones, bosnians, wavell, erroneously, mycelium, amoraim, boroughs,
# Nearest to creation: molloy, presented, woodcuts, tatian, dichotomy, polling, edging, meetings,
# Nearest to freedom: morality, kylix, dedication, publius, mengele, meun, dug, illiteracy,
# Nearest to notes: panarion, uncharacteristic, excitable, ewell, decidedly, stacey, ket, deposing,
# Nearest to primarily: kinesthetic, particularly, monmouth, amphetamine, dihedral, shift, switchable, inflammations,
# Nearest to engineering: systems, versioning, bokassa, fictionalised, forwarding, pokey, postgraduate, openness,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2541 0.2809 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2282 0.2773 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2217 0.2806 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1339 0.2797 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1970 0.2794 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1934 0.2786 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1596 0.2768 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1704 0.2778 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1987 0.2796 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1775 0.2777 sec/batch
# Nearest to people: childbirth, msil, inh, laparoscopic, trafficking, establish, fishing, caribou,
# Nearest to after: oder, wore, to, badly, paveway, landed, linebacker, entered,
# Nearest to states: weimar, faring, united, haworth, deterioration, enacted, galway, representatives,
# Nearest to d: chemist, b, zquez, pearson, flautist, elliott, apparitions, jespersen,
# Nearest to history: bain, encyclopedia, hwang, org, country, glaze, printing, rawls,
# Nearest to and: intake, directv, dentist, unlike, of, hfr, leaps, improv,
# Nearest to however: abrahamic, collectivism, despotism, karoline, intentionally, artefacts, eunos, contemplate,
# Nearest to at: climbing, force, interlocutor, altenburg, kingston, donatists, minoans, home,
# Nearest to active: slopes, libreville, supplemental, basaltic, funding, inoculation, herut, constituents,
# Nearest to animals: mammals, species, aqueous, wolof, afterwards, breeding, agricultural, paleocene,
# Nearest to report: idempotent, gemstones, bosnians, boroughs, wavell, erroneously, proletarians, mycelium,
# Nearest to creation: presented, tatian, molloy, dichotomy, woodcuts, comprehensive, differs, triune,
# Nearest to freedom: morality, kylix, dedication, mengele, meun, suggestive, of, publius,
# Nearest to notes: panarion, stacey, bugtraq, decidedly, ket, uncharacteristic, ewell, excitable,
# Nearest to primarily: particularly, kinesthetic, amphetamine, monmouth, dihedral, switchable, shift, customizable,
# Nearest to engineering: systems, versioning, fictionalised, postgraduate, forwarding, pokey, bokassa, openness,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1764 0.2814 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2291 0.2877 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1879 0.2834 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1742 0.2778 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2099 0.2780 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1833 0.2791 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2126 0.2790 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1395 0.2768 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1356 0.2797 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1617 0.2798 sec/batch
# Nearest to people: msil, laparoscopic, childbirth, inh, trafficking, fishing, caribou, metrorail,
# Nearest to after: oder, badly, wore, landed, to, october, isaac, bringer,
# Nearest to states: weimar, united, faring, deterioration, representatives, haworth, galway, guardia,
# Nearest to d: b, chemist, flautist, zquez, pearson, astronomer, apparitions, elliott,
# Nearest to history: bain, encyclopedia, hwang, org, external, glaze, printing, rawls,
# Nearest to and: intake, dentist, directv, of, rouen, barbecue, unlike, lavey,
# Nearest to however: abrahamic, collectivism, despotism, eunos, discernment, contemplate, artefacts, demonstrated,
# Nearest to at: force, interlocutor, climbing, donatists, minoans, kingston, altenburg, pupil,
# Nearest to active: libreville, slopes, inoculation, supplemental, herut, basaltic, funding, briefcase,
# Nearest to animals: mammals, species, aqueous, wolof, breeding, afterwards, paleocene, agricultural,
# Nearest to report: idempotent, bosnians, gemstones, wavell, boroughs, proletarians, lumber, cnn,
# Nearest to creation: presented, tatian, molloy, woodcuts, dichotomy, comprehensive, differs, meetings,
# Nearest to freedom: morality, kylix, mengele, dedication, illiteracy, of, calvinist, meun,
# Nearest to notes: panarion, stacey, ket, ewell, uncharacteristic, chuck, bugtraq, decidedly,
# Nearest to primarily: kinesthetic, particularly, monmouth, amphetamine, switchable, dihedral, shift, pertain,
# Nearest to engineering: systems, versioning, postgraduate, fictionalised, openness, forwarding, pokey, programs,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1814 0.2820 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1655 0.2795 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1881 0.2772 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1937 0.2814 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1219 0.2790 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1343 0.2778 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1664 0.2774 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1252 0.2808 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1719 0.2812 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2097 0.2817 sec/batch
# Nearest to people: laparoscopic, msil, inh, childbirth, trafficking, entertainers, alphasyllabary, metrorail,
# Nearest to after: oder, wore, to, landed, badly, october, cyrus, linebacker,
# Nearest to states: weimar, united, galway, representatives, guardia, govern, haworth, faring,
# Nearest to d: b, chemist, flautist, zquez, pearson, architect, biographie, elliott,
# Nearest to history: bain, encyclopedia, external, org, hwang, printing, university, comprehensive,
# Nearest to and: of, ivo, rouen, demosthenes, dentist, lavey, rajendra, democrat,
# Nearest to however: abrahamic, collectivism, despotism, eunos, chickasaw, contemplate, intentionally, karoline,
# Nearest to at: force, kingston, interlocutor, minoans, donatists, climbing, after, pupil,
# Nearest to active: libreville, slopes, basaltic, supplemental, inoculation, herut, kroto, constituents,
# Nearest to animals: mammals, species, breeding, wolof, afterwards, aqueous, paleocene, animal,
# Nearest to report: wavell, idempotent, bosnians, cnn, gemstones, boroughs, programme, lumber,
# Nearest to creation: tatian, presented, molloy, woodcuts, dichotomy, comprehensive, polling, meetings,
# Nearest to freedom: morality, kylix, mengele, dedication, meun, kinnock, calvinist, of,
# Nearest to notes: panarion, ket, concentric, stacey, ewell, uncharacteristic, decidedly, bugtraq,
# Nearest to primarily: kinesthetic, particularly, amphetamine, monmouth, dihedral, switchable, shift, ergonomics,
# Nearest to engineering: systems, postgraduate, versioning, openness, forwarding, pokey, bokassa, fictionalised,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2186 0.2799 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1249 0.2847 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1399 0.2779 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1529 0.2777 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0351 0.2779 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1426 0.2795 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1462 0.2777 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1485 0.2780 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1426 0.0536 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1079 0.2790 sec/batch
# Nearest to people: laparoscopic, trafficking, msil, childbirth, inh, establish, entertainers, alphasyllabary,
# Nearest to after: oder, wore, to, badly, landed, cyrus, doggystyle, linebacker,
# Nearest to states: weimar, united, galway, faring, guardia, deterioration, representatives, haworth,
# Nearest to d: b, chemist, flautist, zquez, astronomer, physician, pearson, politician,
# Nearest to history: bain, encyclopedia, external, printing, org, vl, hwang, comprehensive,
# Nearest to and: of, intake, directv, dentist, ivo, because, rajendra, rouen,
# Nearest to however: abrahamic, despotism, collectivism, eunos, intentionally, contemplate, vulnerabilities, zhdanov,
# Nearest to at: force, climbing, kingston, interlocutor, altenburg, shankar, home, minoans,
# Nearest to active: libreville, slopes, basaltic, supplemental, kroto, inoculation, herut, schools,
# Nearest to animals: mammals, species, breeding, wolof, aqueous, afterwards, animal, paleocene,
# Nearest to report: cnn, idempotent, gemstones, wavell, boroughs, bosnians, amoraim, programme,
# Nearest to creation: tatian, molloy, presented, woodcuts, dichotomy, polling, edging, meetings,
# Nearest to freedom: morality, kylix, mengele, kinnock, dedication, bum, meun, suggestive,
# Nearest to notes: panarion, concentric, ket, decidedly, uncharacteristic, stacey, reanimation, bugtraq,
# Nearest to primarily: particularly, kinesthetic, amphetamine, monmouth, shift, ergonomics, dihedral, pertain,
# Nearest to engineering: systems, postgraduate, versioning, openness, bokassa, pokey, electronics, heaney,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0921 0.2861 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0571 0.2806 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0956 0.2795 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0679 0.2781 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0995 0.2796 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0327 0.2800 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0745 0.3177 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0705 0.3117 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1172 0.2625 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0651 0.2654 sec/batch
# Nearest to people: childbirth, laparoscopic, inh, trafficking, msil, entertainers, alphasyllabary, amnon,
# Nearest to after: to, oder, badly, wore, doggystyle, entered, landed, at,
# Nearest to states: united, weimar, faring, govern, galway, declaration, recognizing, haworth,
# Nearest to d: b, chemist, flautist, zquez, jespersen, biographie, brereton, astronomer,
# Nearest to history: bain, encyclopedia, external, printing, hwang, glaze, comprehensive, country,
# Nearest to and: of, intake, directv, including, being, dentist, unlike, leaps,
# Nearest to however: abrahamic, despotism, collectivism, chickasaw, eunos, intentionally, keiy, marked,
# Nearest to at: force, minoans, after, interlocutor, climbing, donatists, naci, runway,
# Nearest to active: libreville, slopes, supplemental, basaltic, inoculation, kroto, herut, tsunami,
# Nearest to animals: mammals, species, breeding, wolof, aqueous, afterwards, animal, paleocene,
# Nearest to report: cnn, wavell, bosnians, idempotent, gemstones, programme, amoraim, boroughs,
# Nearest to creation: tatian, molloy, presented, dichotomy, woodcuts, comprehensive, edging, meetings,
# Nearest to freedom: morality, kylix, mengele, kinnock, dedication, suggestive, illiteracy, meun,
# Nearest to notes: panarion, stacey, decidedly, concentric, beaufort, uncharacteristic, reanimation, bugtraq,
# Nearest to primarily: particularly, kinesthetic, amphetamine, monmouth, ergonomics, shift, glas, dihedral,
# Nearest to engineering: postgraduate, systems, versioning, openness, pokey, heaney, electronics, bokassa,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0276 0.2679 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0348 0.2628 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0136 0.2611 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0851 0.2626 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0819 0.2643 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0505 0.2628 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0581 0.2621 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0918 0.2641 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0444 0.2660 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0586 0.2639 sec/batch
# Nearest to people: laparoscopic, trafficking, childbirth, inh, entertainers, msil, alphasyllabary, communities,
# Nearest to after: oder, doggystyle, to, wore, badly, october, linebacker, at,
# Nearest to states: united, weimar, faring, haworth, recognizing, govern, deterioration, guardia,
# Nearest to d: b, flautist, chemist, jespersen, biographie, rieure, rsted, zquez,
# Nearest to history: bain, encyclopedia, hwang, external, printing, glaze, rawls, fanfic,
# Nearest to and: of, intake, directv, a, hfr, dentist, rouen, ivo,
# Nearest to however: abrahamic, collectivism, despotism, eunos, intentionally, chickasaw, keiy, contemplate,
# Nearest to at: force, interlocutor, climbing, minoans, after, nfc, home, pupil,
# Nearest to active: libreville, slopes, basaltic, supplemental, herut, inoculation, constituents, ribosome,
# Nearest to animals: mammals, species, breeding, wolof, aqueous, animal, vertebrate, afterwards,
# Nearest to report: cnn, wavell, idempotent, bosnians, amoraim, boroughs, gemstones, programme,
# Nearest to creation: tatian, comprehensive, molloy, presented, dichotomy, meetings, woodcuts, edging,
# Nearest to freedom: morality, mengele, kylix, kinnock, calvinist, of, illiteracy, dedication,
# Nearest to notes: panarion, concentric, stacey, reanimation, decidedly, ket, diatonic, account,
# Nearest to primarily: particularly, kinesthetic, amphetamine, monmouth, shift, ergonomics, pertain, glas,
# Nearest to engineering: postgraduate, systems, openness, versioning, electronics, pokey, heaney, stipend,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0561 0.2670 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0599 0.2646 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1225 0.2647 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0751 0.2628 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0232 0.2650 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0624 0.2653 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0771 0.2649 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0422 0.2673 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0861 0.2638 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0759 0.2623 sec/batch
# Nearest to people: laparoscopic, childbirth, trafficking, entertainers, inh, metrorail, alphasyllabary, boosting,
# Nearest to after: oder, to, october, badly, doggystyle, wore, at, dailies,
# Nearest to states: united, weimar, haworth, guardia, recognizing, faring, govern, deterioration,
# Nearest to d: b, flautist, jespersen, biographie, chemist, bal, rieure, espa,
# Nearest to history: bain, encyclopedia, hwang, printing, external, glaze, friesland, comprehensive,
# Nearest to and: of, intake, directv, rouen, ivo, deceased, dangerously, because,
# Nearest to however: abrahamic, despotism, collectivism, chickasaw, intentionally, marked, eunos, likely,
# Nearest to at: force, minoans, interlocutor, after, naci, dependents, pupil, donatists,
# Nearest to active: libreville, slopes, ribosome, basaltic, receptors, supplemental, kroto, inoculation,
# Nearest to animals: mammals, species, breeding, wolof, animal, aqueous, fossils, vertebrate,
# Nearest to report: cnn, wavell, bosnians, programme, idempotent, intelligence, chemists, amoraim,
# Nearest to creation: tatian, comprehensive, presented, molloy, discussion, meetings, woodcuts, manar,
# Nearest to freedom: morality, mengele, kylix, kinnock, illiteracy, merging, philatelic, calvinist,
# Nearest to notes: concentric, stacey, panarion, reanimation, account, diatonic, gauges, bugtraq,
# Nearest to primarily: particularly, kinesthetic, amphetamine, monmouth, pertain, suggests, ergonomics, shift,
# Nearest to engineering: postgraduate, systems, versioning, openness, electronics, pokey, stipend, heaney,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0320 0.2675 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9955 0.2646 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0675 0.2630 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0733 0.2652 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0582 0.2655 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1056 0.2652 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1463 0.2638 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0030 0.2655 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0564 0.2633 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0454 0.2621 sec/batch
# Nearest to people: entertainers, trafficking, childbirth, laparoscopic, inh, alphasyllabary, ratsiraka, lgbt,
# Nearest to after: oder, to, wore, at, october, shortly, doggystyle, entered,
# Nearest to states: united, recognizing, weimar, haworth, guardia, galway, govern, oi,
# Nearest to d: b, chemist, flautist, biographie, jespersen, bal, zquez, rieure,
# Nearest to history: bain, encyclopedia, hwang, external, glaze, printing, krug, handbook,
# Nearest to and: of, intake, a, ivo, directv, including, rouen, because,
# Nearest to however: abrahamic, chickasaw, despotism, collectivism, eunos, intentionally, zhdanov, karoline,
# Nearest to at: force, after, kingston, minoans, donatists, dependents, naci, pupil,
# Nearest to active: libreville, kroto, basaltic, ribosome, receptors, supplemental, slopes, inoculation,
# Nearest to animals: mammals, breeding, species, wolof, animal, vertebrate, afterwards, aqueous,
# Nearest to report: cnn, wavell, illegal, idempotent, programme, amoraim, chemists, bosnians,
# Nearest to creation: tatian, molloy, presented, comprehensive, discussion, woodcuts, dichotomy, manar,
# Nearest to freedom: morality, mengele, kylix, kinnock, merging, philatelic, bum, dedication,
# Nearest to notes: concentric, panarion, account, reanimation, diatonic, stacey, jerk, gauges,
# Nearest to primarily: particularly, kinesthetic, amphetamine, pertain, monmouth, ergonomics, shift, suggests,
# Nearest to engineering: postgraduate, systems, versioning, openness, electronics, heaney, pokey, stipend,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9609 0.2675 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0063 0.2667 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0302 0.2664 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0294 0.2657 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0749 0.2649 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0237 0.2456 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9998 0.2662 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9986 0.2654 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0060 0.2633 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9625 0.2662 sec/batch
# Nearest to people: laparoscopic, childbirth, entertainers, ratsiraka, trafficking, inh, alphasyllabary, metrorail,
# Nearest to after: oder, at, to, october, shortly, wore, doggystyle, entered,
# Nearest to states: united, recognizing, jai, oi, galway, haworth, guardia, weimar,
# Nearest to d: b, chemist, flautist, biographie, zquez, bal, jespersen, dietrich,
# Nearest to history: bain, encyclopedia, glaze, external, printing, hwang, krug, vl,
# Nearest to and: of, ivo, a, directv, with, evangelica, rajendra, rouen,
# Nearest to however: abrahamic, despotism, collectivism, intentionally, chickasaw, obscurity, keiy, contemplate,
# Nearest to at: after, force, minoans, dependents, kingston, donatists, home, naci,
# Nearest to active: libreville, supplemental, kroto, slopes, ribosome, basaltic, receptors, herut,
# Nearest to animals: mammals, species, breeding, animal, wolof, aqueous, fossils, vertebrate,
# Nearest to report: cnn, wavell, idempotent, chemists, illegal, programme, amoraim, studies,
# Nearest to creation: tatian, molloy, presented, meetings, comprehensive, manar, woodcuts, dichotomy,
# Nearest to freedom: morality, mengele, kylix, kinnock, merging, bum, philatelic, dedication,
# Nearest to notes: concentric, diatonic, account, reanimation, panarion, decidedly, gauges, stacey,
# Nearest to primarily: particularly, amphetamine, kinesthetic, ergonomics, suggests, shift, pertain, aerials,
# Nearest to engineering: postgraduate, systems, electronics, versioning, openness, pokey, stipend, dustin,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9731 0.2689 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9546 0.2655 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9921 0.2703 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0089 0.2641 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0166 0.2648 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0086 0.2644 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9276 0.2651 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9726 0.2643 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9464 0.2626 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9763 0.2640 sec/batch
# Nearest to people: laparoscopic, entertainers, childbirth, ratsiraka, trafficking, ancestries, alphasyllabary, persons,
# Nearest to after: to, at, oder, the, october, doggystyle, division, badly,
# Nearest to states: united, recognizing, jai, haworth, faring, oi, north, fense,
# Nearest to d: b, flautist, biographie, jespersen, zquez, chemist, espa, rieure,
# Nearest to history: encyclopedia, bain, external, glaze, hwang, printing, mainstay, byzantine,
# Nearest to and: of, a, intake, with, the, ivo, is, deceased,
# Nearest to however: abrahamic, intentionally, chickasaw, keiy, marked, collectivism, contemplate, obscurity,
# Nearest to at: after, home, dependents, force, when, to, climbing, altenburg,
# Nearest to active: libreville, receptors, supplemental, ribosome, slopes, basaltic, uhf, inoculation,
# Nearest to animals: mammals, breeding, species, animal, aqueous, wolof, fossils, afterwards,
# Nearest to report: cnn, illegal, programme, chemists, idempotent, studies, wavell, intelligence,
# Nearest to creation: tatian, comprehensive, presented, molloy, differs, meetings, dichotomy, manar,
# Nearest to freedom: morality, mengele, kylix, kinnock, merging, espouse, philatelic, animals,
# Nearest to notes: concentric, diatonic, account, gauges, reanimation, decidedly, emeralds, frets,
# Nearest to primarily: particularly, amphetamine, kinesthetic, suggests, ergonomics, pertain, aerials, monmouth,
# Nearest to engineering: postgraduate, systems, electronics, versioning, openness, stipend, heaney, pokey,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9901 0.2691 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0138 0.2626 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9907 0.2628 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0008 0.2626 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0329 0.2633 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9598 0.2639 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0058 0.2641 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9890 0.2646 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0017 0.2659 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0176 0.2624 sec/batch
# Nearest to people: laparoscopic, entertainers, ratsiraka, childbirth, ancestries, trafficking, alphasyllabary, inh,
# Nearest to after: at, oder, to, shortly, doggystyle, october, badly, entered,
# Nearest to states: united, recognizing, jai, haworth, north, oi, truk, guardia,
# Nearest to d: b, flautist, biographie, bal, chemist, timbaland, zquez, espa,
# Nearest to history: encyclopedia, bain, external, glaze, hwang, handbook, printing, vl,
# Nearest to and: of, a, with, intake, ivo, the, barbecue, to,
# Nearest to however: abrahamic, despotism, chickasaw, keiy, obscurity, marked, likely, intentionally,
# Nearest to at: after, quorum, pupil, force, home, when, minoans, donatists,
# Nearest to active: libreville, receptors, ribosome, supplemental, slopes, uhf, basaltic, herut,
# Nearest to animals: mammals, breeding, species, animal, aqueous, wolof, fossils, ability,
# Nearest to report: cnn, illegal, programme, studies, chemists, idempotent, wavell, intelligence,
# Nearest to creation: tatian, comprehensive, molloy, presented, discussion, differs, creationists, manar,
# Nearest to freedom: morality, mengele, kylix, kinnock, philatelic, espouse, calvinist, merging,
# Nearest to notes: concentric, account, diatonic, reanimation, gauges, panarion, stacey, bugtraq,
# Nearest to primarily: particularly, amphetamine, kinesthetic, pertain, suggests, ergonomics, monmouth, paleontologists,
# Nearest to engineering: postgraduate, systems, electronics, versioning, stipend, processing, pokey, oceanography,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0178 0.2689 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9801 0.2653 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9755 0.2633 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9963 0.2874 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0266 0.2682 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9959 0.2670 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9773 0.2663 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9480 0.2693 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9839 0.2706 sec/batch
# ...
# Nearest to and: of, with, in, the, a, to, is, or,
# Nearest to however: fact, abrahamic, intentionally, widely, as, surprisingly, likely, lesser,
# Nearest to at: after, when, to, the, minutes, totals, in, later,
# Nearest to active: receptors, actively, uhf, ribosome, volcano, supplemental, predominately, critiques,
# Nearest to animals: mammals, animal, ability, breeding, aqueous, bicontinental, diprotodon, submarines,
# Nearest to report: programme, reports, roe, illegal, studies, chemists, cnn, argues,
# Nearest to creation: tatian, creationists, ih, mommsen, molloy, differs, comprehensive, triune,
# Nearest to freedom: kinnock, philatelic, monophosphate, espouse, morality, hayek, radhakrishnan, mengele,
# Nearest to notes: diatonic, account, frets, reanimation, strangeness, gauges, presses, concentric,
# Nearest to primarily: mostly, particularly, and, suggests, pertain, some, husbandry, actions,
# Nearest to engineering: postgraduate, systems, electronics, orville, oceanography, zoology, flowchart, emsworth,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8439 0.2814 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8737 0.2775 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8458 0.2768 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8434 0.2782 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8594 0.2760 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8805 0.2777 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8675 0.2806 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8488 0.2788 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8799 0.2782 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8516 0.2793 sec/batch
# Nearest to people: entertainers, births, deaths, ratsiraka, living, lgbt, ancestries, oscar,
# Nearest to after: at, to, shortly, the, of, entered, had, dailies,
# Nearest to states: united, countries, truk, nagel, recognizing, u, iroquois, jai,
# Nearest to d: flautist, posner, topical, madeleine, zaires, robinson, appendant, b,
# Nearest to history: external, see, encyclopedia, the, press, vl, glaze, photos,
# Nearest to and: of, with, the, in, a, to, by, most,
# Nearest to however: surprisingly, fact, as, most, likely, abrahamic, widely, intentionally,
# Nearest to at: after, when, of, to, the, later, in, totals,
# Nearest to active: receptors, actively, uhf, predominately, ribosome, volcano, critiques, broaden,
# Nearest to animals: mammals, breeding, animal, ability, aqueous, diprotodon, bicontinental, ericaceae,
# Nearest to report: programme, reports, chemists, roe, studies, illegal, cnn, guelleh,
# Nearest to creation: creationists, tatian, ih, triune, bhaktivedanta, molloy, genesis, differs,
# Nearest to freedom: philatelic, kinnock, monophosphate, mengele, morality, liberties, recipients, constants,
# Nearest to notes: account, diatonic, frets, reanimation, gauges, strangeness, roberta, presses,
# Nearest to primarily: mostly, and, pertain, particularly, suggests, some, francophones, ulmanis,
# Nearest to engineering: postgraduate, electronics, systems, oceanography, flowchart, orville, evolved, zoology,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8416 0.2817 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8478 0.2780 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8453 0.2791 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8382 0.2759 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9038 0.2789 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8568 0.2808 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9894 0.2813 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8604 0.2769 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8983 0.2782 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8098 0.2803 sec/batch
# Nearest to people: births, entertainers, deaths, ratsiraka, living, sundanese, ancestries, malan,
# Nearest to after: at, to, shortly, the, first, later, entered, dailies,
# Nearest to states: united, countries, nagel, truk, recognizing, war, u, law,
# Nearest to d: flautist, b, chemist, posner, madeleine, robinson, zaires, siskel,
# Nearest to history: external, see, encyclopedia, press, photos, vl, the, timeline,
# Nearest to and: of, with, the, in, a, to, such, including,
# Nearest to however: intentionally, surprisingly, abrahamic, fact, most, scenarios, widely, actual,
# Nearest to at: after, when, of, later, he, in, to, the,
# Nearest to active: receptors, actively, critiques, predominately, uhf, volcano, ribosome, broaden,
# Nearest to animals: mammals, ability, breeding, animal, aqueous, skunk, bicontinental, diprotodon,
# Nearest to report: reports, programme, cnn, roe, illegal, chemists, guelleh, studies,
# Nearest to creation: creationists, tatian, ih, molloy, bhaktivedanta, manar, conservation, triune,
# Nearest to freedom: kinnock, philatelic, monophosphate, recipients, mengele, bum, liberties, morality,
# Nearest to notes: diatonic, frets, account, reanimation, strangeness, presses, gauges, roberta,
# Nearest to primarily: mostly, and, particularly, some, pertain, suggests, such, faction,
# Nearest to engineering: postgraduate, electronics, systems, oceanography, peace, orville, flowchart, maskelyne,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8238 0.2812 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8502 0.2783 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8202 0.2789 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8724 0.2802 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8251 0.2799 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8559 0.2781 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9101 0.1599 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8190 0.3021 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8499 0.3020 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8489 0.2990 sec/batch
# Nearest to people: births, entertainers, deaths, living, ratsiraka, sundanese, grave, natives,
# Nearest to after: at, shortly, to, the, his, first, of, entered,
# Nearest to states: united, countries, war, nagel, truk, u, in, recognizing,
# Nearest to d: b, flautist, chemist, admiral, siskel, writer, publisher, madeleine,
# Nearest to history: external, see, encyclopedia, press, vl, photos, the, timeline,
# Nearest to and: of, with, the, in, a, to, by, such,
# Nearest to however: surprisingly, most, abrahamic, intentionally, actual, fact, previous, lesser,
# Nearest to at: after, the, of, in, later, he, when, to,
# Nearest to active: actively, volcano, uhf, receptors, critiques, broaden, predominately, ribosome,
# Nearest to animals: ability, animal, mammals, breeding, aqueous, diprotodon, submarines, bicontinental,
# Nearest to report: reports, programme, cnn, roe, illegal, chemists, studies, guelleh,
# Nearest to creation: tatian, creationists, ih, bhaktivedanta, molloy, manar, mommsen, triune,
# Nearest to freedom: kinnock, monophosphate, philatelic, recipients, mengele, constants, bum, sahara,
# Nearest to notes: diatonic, frets, account, reanimation, strangeness, gauges, presses, concentric,
# Nearest to primarily: mostly, particularly, pertain, suggests, more, native, such, some,
# Nearest to engineering: postgraduate, electronics, systems, oceanography, orville, flowchart, maskelyne, peace,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8552 0.2790 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8310 0.2760 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8194 0.2777 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8049 0.2747 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8629 0.2760 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8189 0.2747 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8875 0.2772 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7587 0.2762 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8155 0.2746 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8075 0.2749 sec/batch
# Nearest to people: births, entertainers, deaths, living, ratsiraka, natives, ancestries, lgbt,
# Nearest to after: at, to, the, shortly, first, into, entered, had,
# Nearest to states: united, countries, war, in, truk, u, nagel, of,
# Nearest to d: flautist, zaires, b, posner, madeleine, technion, robinson, pittsfield,
# Nearest to history: external, see, encyclopedia, press, the, world, photos, vl,
# Nearest to and: of, in, with, the, a, to, is, such,
# Nearest to however: abrahamic, surprisingly, most, not, fact, intentionally, previous, being,
# Nearest to at: after, of, the, in, to, totals, when, also,
# Nearest to active: actively, volcano, receptors, uhf, facilitates, ribosome, predominately, prd,
# Nearest to animals: ability, animal, breeding, mammals, aqueous, diprotodon, bicontinental, submarines,
# Nearest to report: reports, programme, illegal, cnn, roe, chemists, studies, guelleh,
# Nearest to creation: tatian, creationists, ih, triune, manar, genesis, molloy, bhaktivedanta,
# Nearest to freedom: kinnock, philatelic, monophosphate, recipients, constants, sahara, bum, radhakrishnan,
# Nearest to notes: diatonic, frets, account, reanimation, gauges, strangeness, presses, concentric,
# Nearest to primarily: mostly, and, some, in, pertain, particularly, also, more,
# Nearest to engineering: postgraduate, systems, electronics, orville, flowchart, peace, oceanography, maskelyne,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7690 0.2758 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8090 0.2752 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8543 0.2760 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8156 0.2829 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8348 0.2751 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8964 0.2766 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8618 0.2766 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8438 0.2757 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8563 0.2752 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8555 0.2761 sec/batch
# Nearest to people: births, entertainers, living, deaths, ancestries, natives, oscar, lgbt,
# Nearest to after: shortly, at, to, had, dailies, first, entered, the,
# Nearest to states: united, countries, in, nagel, war, recognizing, truk, north,
# Nearest to d: flautist, zaires, b, robinson, topical, posner, technion, pittsfield,
# Nearest to history: external, see, encyclopedia, press, photos, vl, timeline, the,
# Nearest to and: of, with, in, the, a, to, or, most,
# Nearest to however: most, not, surprisingly, fact, abrahamic, being, as, of,
# Nearest to at: of, after, the, in, to, when, also, required,
# Nearest to active: actively, uhf, volcano, facilitates, critiques, receptors, predominately, prd,
# Nearest to animals: animal, ability, mammals, breeding, aqueous, diprotodon, bicontinental, instinct,
# Nearest to report: reports, programme, illegal, cnn, studies, guelleh, chemists, roe,
# Nearest to creation: creationists, tatian, ih, genesis, triune, molloy, bhaktivedanta, manar,
# Nearest to freedom: kinnock, philatelic, monophosphate, constants, recipients, freedoms, sahara, mengele,
# Nearest to notes: diatonic, frets, account, reanimation, strangeness, roberta, presses, gauges,
# Nearest to primarily: mostly, pertain, some, more, particularly, in, and, suggests,
# Nearest to engineering: postgraduate, electronics, systems, orville, flowchart, evolved, oceanography, peace,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8495 0.2825 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8612 0.2763 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8229 0.2782 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8366 0.2805 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8717 0.2800 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8395 0.2826 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8312 0.2763 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8474 0.2800 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8063 0.2755 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8174 0.2759 sec/batch
# Nearest to people: births, deaths, entertainers, living, natives, ancestries, ratsiraka, winners,
# Nearest to after: to, at, shortly, the, entered, dailies, had, later,
# Nearest to states: united, countries, recognizing, war, law, in, u, nagel,
# Nearest to d: flautist, zaires, topical, pittsfield, posner, b, technion, madeleine,
# Nearest to history: external, see, encyclopedia, timeline, the, press, vl, world,
# Nearest to and: of, with, the, in, to, a, or, such,
# Nearest to however: most, surprisingly, not, as, abrahamic, the, of, but,
# Nearest to at: of, to, the, after, in, when, also, later,
# Nearest to active: actively, receptors, volcano, facilitates, critiques, uhf, ribosome, predominately,
# Nearest to animals: animal, ability, mammals, breeding, aqueous, diprotodon, instinct, skunk,
# Nearest to report: reports, programme, illegal, cnn, chemists, guelleh, studies, foia,
# Nearest to creation: creationists, tatian, triune, genesis, ih, turnover, manar, bhaktivedanta,
# Nearest to freedom: kinnock, philatelic, monophosphate, recipients, constants, sahara, mengele, freedoms,
# Nearest to notes: diatonic, frets, account, reanimation, presses, gauges, strangeness, concentric,
# Nearest to primarily: mostly, and, more, some, in, pertain, ulmanis, such,
# Nearest to engineering: postgraduate, electronics, systems, orville, flowchart, oceanography, evolved, peace,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8727 0.2828 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7913 0.2793 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9122 0.2934 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8960 0.2762 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8894 0.2745 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8295 0.2771 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7765 0.2753 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8511 0.2761 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7187 0.2768 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8717 0.2773 sec/batch
# Nearest to people: births, entertainers, living, deaths, natives, ratsiraka, ancestries, sundanese,
# Nearest to after: shortly, to, at, dailies, entered, later, had, returned,
# Nearest to states: united, countries, war, recognizing, u, nagel, part, in,
# Nearest to d: b, physicist, writer, flautist, chemist, astronomer, posner, pittsfield,
# Nearest to history: see, external, encyclopedia, timeline, photos, the, press, vl,
# Nearest to and: of, the, with, in, a, to, such, or,
# Nearest to however: surprisingly, most, abrahamic, but, actual, fact, criminalized, as,
# Nearest to at: of, in, after, to, when, the, later, also,
# Nearest to active: actively, receptors, volcano, critiques, facilitates, broaden, uhf, ribosome,
# Nearest to animals: animal, ability, breeding, mammals, aqueous, diprotodon, skunk, submarines,
# Nearest to report: reports, illegal, programme, cnn, chemists, guelleh, studies, foia,
# Nearest to creation: creationists, tatian, ih, turnover, bhaktivedanta, genesis, triune, molloy,
# Nearest to freedom: kinnock, philatelic, recipients, monophosphate, sahara, freedoms, bum, ngo,
# Nearest to notes: diatonic, frets, account, reanimation, strangeness, presses, gauges, argumentative,
# Nearest to primarily: mostly, in, and, more, some, ulmanis, particularly, pertain,
# Nearest to engineering: postgraduate, systems, electronics, orville, flowchart, oceanography, peace, expositor,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8305 0.2905 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8308 0.2836 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
